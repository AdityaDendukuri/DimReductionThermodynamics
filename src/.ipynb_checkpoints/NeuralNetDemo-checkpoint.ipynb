# %%
# %matplotlib inline
from dataloader import *
from plotter import *
from neural_net import *
from scripts import *

# %%
#load dataset
features = load_features("../data/3P_ROTATED_COORDINATES.txt")
labels = load_labels("../data/3P_T018_POTENTIALS.txt", 1)
x = []
y = []
z = []
c = []
for i in range(len(features)):
    for j in range(0, len(features[i]), 3):
        x.append(features[i][j+0])
        y.append(features[i][j+1])  
        z.append(features[i][j+2])
        c.append(labels[i])
plot_3d(x, y, z, color=np.reshape(c, len(c)))
# Out:
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-d8739b8a7ea5> in <module>()
#       1 #load dataset
# ----> 2 features = load_features("../data/3P_CENTERED_COORDINATES.txt")
#       3 labels = load_labels("../data/3P_T018_POTENTIALS.txt", 1)
#       4 x = []
#       5 y = []
#
# /Users/DPCRAO/adisrepo/DimReductionThermodynamics/src/dataloader.py in load_features(path)
#      20         i=0
#      21         for i in range(9):
# ---> 22             temp.append(float(data[i]))
#      23         features.append(temp)
#      24     return np.reshape(features, [len(np.asarray(features)), 9])
#
# IndexError: list index out of range

# %%
#define Structure of neural net
structure = [9, 20, 20, 5, 2, 1]
activations = ['tanh', 'tanh', 'tanh', 'tanh', 'tanh', 'tanh']
model_dir = "../models/T018_8.ckpt"

#initialize neural network and train
nn = NEURAL_NET(3, structure, activations)
nn.learning_rate = 0.1
nn.train(features, labels, test_set_size=2000, num_steps=10000, save=True, restore=True, model_save_dir=model_dir)


reduced_space = nn.get_reduced_space(features, model_dir)
predicted_potentials = nn.get_output_space(features, model_dir)
plot_2d(reduced_space[:, 0], reduced_space[:, 1], color=labels.flatten())
# Out:
# 0
# 1
# 2
# 3
# INFO:tensorflow:Restoring parameters from ../models/T018_8.ckpt
# Step 1, Loss = 0.0205
# Step 1000, Loss = 0.0202
# Step 2000, Loss = 0.0210
# Step 3000, Loss = 0.0185
# Step 4000, Loss = 0.0189
# Step 5000, Loss = 0.0185
# Step 6000, Loss = 0.0197
# Step 7000, Loss = 0.0184
# Step 8000, Loss = 0.0185
# Step 9000, Loss = 0.0189
# Step 10000, Loss = 0.0192
#
#
#  TRAINING COMPLETE. LOSS: 0.0192
# INFO:tensorflow:Restoring parameters from ../models/T018_8.ckpt
# INFO:tensorflow:Restoring parameters from ../models/T018_8.ckpt

# %%
averages = []
for i in range(len(features)):
    p1 = features[i][0:3]
    p2 = features[i][3:6]    
    p3 = features[i][6:9]

# %%
plot_2d(reduced_space[:,1], labels)
